# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
from drizzlepac import tweakreg
from drizzlepac import astrodrizzle
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
from drizzlepac import staticMask, sky, adrizzle, createMedian, ablot, drizCR

# %%
astrodrizzle.AstroDrizzle('./jdan21*flc.fits',driz_cr=True,driz_cr_corr=True)
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.0.2 (2019-05-28 16:51:22 -0400) started at: 19:07:11.658 (17/03/2020)
#
# ==== Processing Step  Initialization  started at  19:07:11.663 (17/03/2020)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 43.88789573695689  -54.11849525420317
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.2871196611193363e-06  -1.382911991219475e-05
# CD2_1 CD2_2  : -1.382911991219475e-05  1.2871196611193363e-06
# NAXIS : 4215  4246
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 1075 Mb.
# *  Output image size:       4215 X 4246 pixels.
# *  Output image file:       ~ 204 Mb.
# *  Cores available:         4
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  19:07:19.648 (17/03/2020)
#
# ==== Processing Step  Static Mask  started at  19:07:19.6 (17/03/2020)
# ==== Processing Step  Static Mask  finished at  19:07:27.068 (17/03/2020)
#
# ==== Processing Step  Subtract Sky  started at  19:07:27.070 (17/03/2020)
# ***** skymatch started on 2020-03-17 19:07:28.722202
#       Version 1.0.4 (2019-05-30 14:31:23 -0400)
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'jdan21l8q_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21l8q_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21l8q_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21laq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21laq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21laq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21lfq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21lfq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21lfq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21lhq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21lhq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21lhq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21llq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21llq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21llq_skymatch_mask_sci2.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = None
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: jdan21l8q_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#
#    *   Image: jdan21laq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#
#    *   Image: jdan21lfq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 100.0 [s]
#              Conversion factor (data->brightness):  3.9999999999999996
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 100.0 [s]
#              Conversion factor (data->brightness):  3.9999999999999996
#
#    *   Image: jdan21lhq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1121.0 [s]
#              Conversion factor (data->brightness):  0.3568242640499553
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1121.0 [s]
#              Conversion factor (data->brightness):  0.3568242640499553
#
#    *   Image: jdan21llq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1122.0 [s]
#              Conversion factor (data->brightness):  0.35650623885918
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1122.0 [s]
#              Conversion factor (data->brightness):  0.35650623885918
#
#
# -----  Computing sky values requested image extensions (detector chips):  -----
#
#    *   Image:   'jdan21l8q_flc.fits['SCI',1,2]'  --  SKY = 18.47485677582161 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 52.7457   NEW MDRIZSKY = 52.7457
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 52.7457   NEW MDRIZSKY = 52.7457
#    *   Image:   'jdan21laq_flc.fits['SCI',1,2]'  --  SKY = 23.59604710246552 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 67.3667   NEW MDRIZSKY = 67.3667
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 67.3667   NEW MDRIZSKY = 67.3667
#    *   Image:   'jdan21lfq_flc.fits['SCI',1,2]'  --  SKY = 18.192197799682614 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 4.54805   NEW MDRIZSKY = 4.54805
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 4.54805   NEW MDRIZSKY = 4.54805
#    *   Image:   'jdan21lhq_flc.fits['SCI',1,2]'  --  SKY = 18.385535452006437 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 51.5255   NEW MDRIZSKY = 51.5255
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 51.5255   NEW MDRIZSKY = 51.5255
#    *   Image:   'jdan21llq_flc.fits['SCI',1,2]'  --  SKY = 19.858621743486097 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 55.7034   NEW MDRIZSKY = 55.7034
#       - EXT = 'SCI',2   delta(MDRIZSKY) = 55.7034   NEW MDRIZSKY = 55.7034
# ***** skymatch ended on 2020-03-17 19:07:33.831338
# TOTAL RUN TIME: 0:00:05.109136
# ==== Processing Step  Subtract Sky  finished at  19:07:38.632 (17/03/2020)
#
# ==== Processing Step  Separate Drizzle  started at  19:07:38.634 (17/03/2020)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 43.88789573695689  -54.11849525420317
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.2871196611193363e-06  -1.382911991219475e-05
# CD2_1 CD2_2  : -1.382911991219475e-05  1.2871196611193363e-06
# NAXIS : 4215  4246
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_single_wht.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_single_sci.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_single_sci.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_single_wht.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_single_wht.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_single_wht.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_single_wht.fits
# ==== Processing Step  Separate Drizzle  finished at  19:08:02.323 (17/03/2020)
#
# ==== Processing Step  Create Median  started at  19:08:02.327 (17/03/2020)
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_flc.fits' is 52.7457160949707
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_flc.fits' is 67.36671447753906
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_flc.fits' is 4.548049449920654
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_flc.fits' is 51.52546310424805
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_flc.fits' is 55.70343399047851
# Saving output median image to: 'final_med.fits'
# ==== Processing Step  Create Median  finished at  19:08:21.83 (17/03/2020)
#
# ==== Processing Step  Blot  started at  19:08:21.833 (17/03/2020)
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_sci2_blt.fits
# ==== Processing Step  Blot  finished at  19:08:41.95 (17/03/2020)
#
# ==== Processing Step  Driz_CR  started at  19:08:41.953 (17/03/2020)
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_sci2_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_sci2_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_sci2_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_sci2_crmask.fits
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lhq_crclean.fits'
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21l8q_crclean.fits'
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21laq_crclean.fits'
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21lfq_crclean.fits'
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_sci2_crmask.fits
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/hor1flcs/jdan21llq_crclean.fits'
# ==== Processing Step  Driz_CR  finished at  19:09:23.895 (17/03/2020)
#
# ==== Processing Step  Final Drizzle  started at  19:09:23.922 (17/03/2020)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 43.88789573695689  -54.11849525420317
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.2871196611193363e-06  -1.382911991219475e-05
# CD2_1 CD2_2  : -1.382911991219475e-05  1.2871196611193363e-06
# NAXIS : 4215  4246
# -Generating simple FITS output: final_drc_sci.fits
# Writing out image to disk: final_drc_sci.fits
# Writing out image to disk: final_drc_wht.fits
# Writing out image to disk: final_drc_ctx.fits
# ==== Processing Step  Final Drizzle  finished at  19:10:04.475 (17/03/2020)
#
#
# AstroDrizzle Version 3.0.2 is finished processing at 19:10:04.479 (17/03/2020).
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          7.9852 sec.
#             Static Mask          7.4099 sec.
#            Subtract Sky          11.5622 sec.
#        Separate Drizzle          23.6888 sec.
#           Create Median          19.5032 sec.
#                    Blot          20.1163 sec.
#                 Driz_CR          41.9423 sec.
#           Final Drizzle          40.5524 sec.
#    ====================          ====================
#                   Total          172.7603 sec.
# Trailer file written to:  astrodrizzle.log
