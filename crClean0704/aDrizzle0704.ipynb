# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
from drizzlepac import tweakreg
from drizzlepac import astrodrizzle
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
from drizzlepac import staticMask, sky, adrizzle, createMedian, ablot, drizCR

# %%
# from astropy.io import fits

# a=fits.getdata('16r12191j_mdz.fits')
# for key,val in zip(a.columns,a[2]): 
#     print(f'{key.name} = {val}')
# Out:
# filter = ANY
# numimages = 4
# mdriztab = True
# refimage =
# runfile =
# coeffs = header
# context = True
# clean = True
# group =
# ra = nan
# dec = nan
# build = True
# gain =
# gnkeyword = ATODGNA,ATODGNB,ATODGNC,ATODGND
# readnoise =
# rnkeyword = READNSEA,READNSEB,READNSEC,READNSED
# exptime = nan
# expkeyword = EXPTIME
# crbitval = 4096
# shiftfile =
# static = True
# staticfile =
# static_sig = 4.0
# subsky = True
# skywidth = 0.10000000149011612
# skystat = median
# skylower = -100.0
# skyupper = nan
# skyclip = 5
# skylsigma = 4.0
# skyusigma = 4.0
# driz_separate = True
# driz_sep_outnx = -2147483647
# driz_sep_outny = -2147483647
# driz_sep_kernel = turbo
# driz_sep_scale = nan
# driz_sep_pixfrac = 1.0
# driz_sep_rot = nan
# driz_sep_fillval = nan
# driz_sep_bits = 336
# median = True
# median_newmasks = True
# combine_type = median
# combine_nsigma = 4 3
# combine_nlow = 0
# combine_nhigh = 1
# combine_lthresh = nan
# combine_hthresh = nan
# combine_grow = 1
# blot = True
# driz_cr = True
# driz_cr_corr = False
# driz_cr_snr = 3.5 3.0
# driz_cr_scale = 1.5 1.2
# driz_combine = True
# final_outnx = -2147483647
# final_outny = -2147483647
# final_kernel = square
# final_scale = nan
# final_pixfrac = 1.0
# final_rot = nan
# final_fillval = nan
# final_bits = 336
# blot_interp = poly5
# blot_sinscl = 1.0

# %%
# astrodrizzle.AstroDrizzle('dirf606w/jdan20*flc.fits',mdriztab=True,driz_cr=True,driz_cr_corr=True,\
#                           skymethod='match',clean=False)

# %%
astrodrizzle.AstroDrizzle('dirf814w/jdan21*flc.fits',\
                          configobj='../astrodrizzle_new.cfg')
# Out:
# Validation warnings for: /Volumes/Spare Data/Hannah_Data/astrodrizzle_new.cfg
# 	"STEP 2: SKY SUBTRACTION.subsky" is an unexpected parameter. Is your file out of date?
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.0.2 (2019-05-28 16:51:22 -0400) started at: 22:49:49.725 (28/04/2020)
#
# ==== Processing Step  Initialization  started at  22:49:49.729 (28/04/2020)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 43.88789557115803  -54.118495413831525
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.2871196611193363e-06  -1.382911991219475e-05
# CD2_1 CD2_2  : -1.382911991219475e-05  1.2871196611193363e-06
# NAXIS : 4215  4246
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 1075 Mb.
# *  Output image size:       4215 X 4246 pixels.
# *  Output image file:       ~ 204 Mb.
# *  Cores available:         4
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  22:49:56.407 (28/04/2020)
#
# ==== Processing Step  Static Mask  started at  22:49:56.417 (28/04/2020)
# ==== Processing Step  Static Mask  finished at  22:50:02.392 (28/04/2020)
#
# ==== Processing Step  Subtract Sky  started at  22:50:02.394 (28/04/2020)
# ***** skymatch started on 2020-04-28 22:50:03.575805
#       Version 1.0.4 (2019-05-30 14:31:23 -0400)
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'jdan21l8q_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21l8q_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21l8q_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21laq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21laq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21laq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21lhq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21lhq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21lhq_skymatch_mask_sci2.fits[0]
#
#    **  Input image: 'jdan21llq_flc.fits'
#        EXT: 'SCI',1;	MASK: jdan21llq_skymatch_mask_sci1.fits[0]
#        EXT: 'SCI',2;	MASK: jdan21llq_skymatch_mask_sci2.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = -100.0
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: jdan21l8q_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#
#    *   Image: jdan21laq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1142.0 [s]
#              Conversion factor (data->brightness):  0.350262697022767
#
#    *   Image: jdan21lhq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1121.0 [s]
#              Conversion factor (data->brightness):  0.3568242640499553
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1121.0 [s]
#              Conversion factor (data->brightness):  0.3568242640499553
#
#    *   Image: jdan21llq_flc.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 1122.0 [s]
#              Conversion factor (data->brightness):  0.35650623885918
#        EXT = 'SCI',2
#              Data units type: COUNTS
#              EXPTIME: 1122.0 [s]
#              Conversion factor (data->brightness):  0.35650623885918
#
#
# -----  Computing differences in sky values in overlapping regions:  -----
#
#    *   Image 'jdan21l8q_flc.fits['SCI',1,2]' SKY = 0.102263 [brightness units]
#        Updating sky of image extension(s) [data units]:
#        -  EXT = 'SCI',1   delta(MDRIZSKY) = 0.291962
#        -  EXT = 'SCI',2   delta(MDRIZSKY) = 0.291962
#
#    *   Image 'jdan21laq_flc.fits['SCI',1,2]' SKY = 5.22358 [brightness units]
#        Updating sky of image extension(s) [data units]:
#        -  EXT = 'SCI',1   delta(MDRIZSKY) = 14.9133
#        -  EXT = 'SCI',2   delta(MDRIZSKY) = 14.9133
#
#    *   Image 'jdan21lhq_flc.fits['SCI',1,2]' SKY = 0 [brightness units]
#        Updating sky of image extension(s) [data units]:
#        -  EXT = 'SCI',1   delta(MDRIZSKY) = 0
#        -  EXT = 'SCI',2   delta(MDRIZSKY) = 0
#
#    *   Image 'jdan21llq_flc.fits['SCI',1,2]' SKY = 1.47781 [brightness units]
#        Updating sky of image extension(s) [data units]:
#        -  EXT = 'SCI',1   delta(MDRIZSKY) = 4.14525
#        -  EXT = 'SCI',2   delta(MDRIZSKY) = 4.14525
#
# ***** skymatch ended on 2020-04-28 22:50:20.240618
# TOTAL RUN TIME: 0:00:16.664813
# ==== Processing Step  Subtract Sky  finished at  22:50:24.523 (28/04/2020)
#
# ==== Processing Step  Separate Drizzle  started at  22:50:24.525 (28/04/2020)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 43.88789557115803  -54.118495413831525
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.2871196611193363e-06  -1.382911991219475e-05
# CD2_1 CD2_2  : -1.382911991219475e-05  1.2871196611193363e-06
# NAXIS : 4215  4246
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_single_sci.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_single_sci.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_single_sci.fits
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_single_sci.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_single_wht.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_single_wht.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_single_wht.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_single_wht.fits
# ==== Processing Step  Separate Drizzle  finished at  22:50:43.714 (28/04/2020)
#
# ==== Processing Step  Create Median  started at  22:50:43.721 (28/04/2020)
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_flc.fits' is 0.2919620802282489
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_flc.fits' is 14.913319426677829
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_flc.fits' is 0.0
# reference sky value for image '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_flc.fits' is 4.145249173094162
# Saving output median image to: 'final_med.fits'
# ==== Processing Step  Create Median  finished at  22:50:54.202 (28/04/2020)
#
# ==== Processing Step  Blot  started at  22:50:54.205 (28/04/2020)
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_sci2_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_flc.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_sci1_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_sci1_blt.fits
#     Blot: creating blotted image:  /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_flc.fits[sci,2]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_sci2_blt.fits
# Writing out image to disk: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_sci2_blt.fits
# ==== Processing Step  Blot  finished at  22:51:10.439 (28/04/2020)
#
# ==== Processing Step  Driz_CR  started at  22:51:10.441 (28/04/2020)
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_sci1_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_sci2_crmask.fits
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21llq_crclean.fits'
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_sci2_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_sci2_crmask.fits
# Creating output: /Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_sci2_crmask.fits
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21laq_crclean.fits'
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21lhq_crclean.fits'
# Created CR corrected file: '/Volumes/Spare Data/Hannah_Data/crClean0704/dirf814w/jdan21l8q_crclean.fits'
# ==== Processing Step  Driz_CR  finished at  22:51:40.235 (28/04/2020)
#
# ==== Processing Step  Final Drizzle  started at  22:51:40.25 (28/04/2020)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 43.88789557115803  -54.118495413831525
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.2871196611193363e-06  -1.382911991219475e-05
# CD2_1 CD2_2  : -1.382911991219475e-05  1.2871196611193363e-06
# NAXIS : 4215  4246
# -Generating multi-extension output file:  final_drc.fits
# Writing out to disk: final_drc.fits
# ==== Processing Step  Final Drizzle  finished at  22:52:11.944 (28/04/2020)
#
#
# AstroDrizzle Version 3.0.2 is finished processing at 22:52:11.949 (28/04/2020).
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          6.6772 sec.
#             Static Mask          5.9750 sec.
#            Subtract Sky          22.1285 sec.
#        Separate Drizzle          19.1889 sec.
#           Create Median          10.4816 sec.
#                    Blot          16.2346 sec.
#                 Driz_CR          29.7936 sec.
#           Final Drizzle          31.6868 sec.
#    ====================          ====================
#                   Total          142.1662 sec.
# Trailer file written to:  astrodrizzle.log

# %%
# hdu1 = fits.open('16r12191j_mdz.fits')

# %%
# hdu1.close()
