# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
psf = np.genfromtxt('elena_cats/HOROLOGIUM_CF.1.PSF.CAT',names=True)
old_sig_sph = np.genfromtxt('HORI_final_1812.dat',names=True)
# new_sig_sph = np.genfromtxt('hor1dir3/HORI_final_sph_1912.dat',names=True)
new_sig_pix = np.genfromtxt('hor1dir3/HORI_pix_2212.dat',names=True)
old_sig_pix = np.genfromtxt('hor1dir3/HORI_pix_1812.dat',names=True)
new_new = np.genfromtxt('hor1dir2312/HORI_pix_2312.dat',names=True) 
# new_sig_pix = np.genfromtxt('HORI_final_1912.dat',names=True)

# %%
print('Old Sig, Sph',len(old_sig_sph))
print('Old Sig, 6 Pix',len(old_sig_pix))
print('New Sig, 6 Pix',len(new_sig_pix))
print('New Sig, 2 Pix',len(new_new))
# Out:
# Old Sig, Sph 1199
# Old Sig, 6 Pix 1232
# New Sig, 6 Pix 1232
# New Sig, 2 Pix 1225

# %%
uncut = np.genfromtxt('hor1dir2/HORI_final_1712.dat',names=True)

# %%
# fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

# ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
# ax1.scatter(old_sig_sph['mean_f606w']-old_sig_sph['mean_f814w'],old_sig_sph['mean_f606w'],
#            label='Old Sig, Sph',alpha=0.5,color='orange')

# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
# # ax2.scatter(new_sig_sph['mean_f606w']-new_sig_sph['mean_f814w'],new_sig_sph['mean_f606w'],
# #            label='New Sig, Sph',alpha=0.5,color='red')

# ax3.scatter(old_sig_sph['mean_f606w']-old_sig_sph['mean_f814w'],old_sig_sph['mean_f606w'],
#            label='Old Sig, Sph',alpha=0.5,color='orange')

# # ax3.scatter(new_sig_sph['mean_f606w']-new_sig_sph['mean_f814w'],new_sig_sph['mean_f606w'],
# #            label='New Sig, Sph',alpha=0.5,color='red')

# ax1.legend()
# ax1.set_ylim(27.5,16)
# ax1.set_xlim(-1,0.5)
# ax1.set_ylabel('F606w-F814W')
# ax2.set_xlabel('F606W')
# ax2.legend()
# ax2.set_ylim(27.5,16)
# ax2.set_xlim(-1,0.5)

# ax3.legend()
# ax3.set_ylim(27.5,16)
# ax3.set_xlim(-1,0.5)

# plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
ax1.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
           label='Old Sig, 6 Pix',alpha=0.5,color='goldenrod')

ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
ax2.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')

ax3.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
           label='Old Sig, 6 Pix',alpha=0.5,color='goldenrod')
ax3.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta',zorder=0)

ax1.legend()
ax1.set_ylim(27.5,16)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606w-F814W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(27.5,16)
ax2.set_xlim(-1,0.5)

ax3.legend()
ax3.set_ylim(27.5,16)
ax3.set_xlim(-1,0.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
ax1.scatter(new_new['mean_f606w']-new_new['mean_f814w'],new_new['mean_f606w'],
           label='New Sig, 2 Pix',alpha=0.5,color='goldenrod')

# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
ax2.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')
ax2.scatter(new_new['mean_f606w']-new_new['mean_f814w'],new_new['mean_f606w'],
           label='New Sig, 2 Pix',alpha=0.5,color='goldenrod')

ax3.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
           label='Old Sig, 6 Pix',alpha=0.5,color='seagreen')
ax3.scatter(new_new['mean_f606w']-new_new['mean_f814w'],new_new['mean_f606w'],
           label='New Sig, 2 Pix',alpha=0.5,color='goldenrod',zorder=1)

ax1.legend()
ax1.set_ylim(27.5,16)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606w-F814W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(27.5,16)
ax2.set_xlim(-1,0.5)

ax3.legend()
ax3.set_ylim(27.5,16)
ax3.set_xlim(-1,0.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
ax1.scatter(new_new['mean_f606w']-new_new['mean_f814w'],new_new['mean_f606w']-0.7,
           label='New Sig, 2 Pix - 0.7',alpha=0.5,color='goldenrod')

# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5)
ax2.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')
ax2.scatter(new_new['mean_f606w']-new_new['mean_f814w'],new_new['mean_f606w']-0.7,
           label='New Sig, 2 Pix - 0.7',alpha=0.5,color='goldenrod')

ax3.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
           label='Old Sig, 6 Pix',alpha=0.5,color='seagreen')
ax3.scatter(new_new['mean_f606w']-new_new['mean_f814w'],new_new['mean_f606w']-0.7,
           label='New Sig, 2 Pix - 0.7',alpha=0.5,color='goldenrod',zorder=1)

ax1.legend()
ax1.set_ylim(27.5,16)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606w-F814W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(27.5,16)
ax2.set_xlim(-1,0.5)

ax3.legend()
ax3.set_ylim(27.5,16)
ax3.set_xlim(-1,0.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5,color='dodgerblue')
ax1.scatter(uncut['median_f606w']-uncut['median_f814w'],uncut['median_f606w'],
           label='Uncut, Sph',alpha=0.5,color='maroon',zorder=1)

ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5,color='dodgerblue')
ax2.scatter(old_sig_sph['mean_f606w']-old_sig_sph['mean_f814w'],old_sig_sph['mean_f606w'],
           label='Old Sig, Sph',alpha=0.5,color='goldenrod')

ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5,color='dodgerblue')
ax3.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')



ax1.legend()
ax1.set_ylim(27.5,16)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606w-F814W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(27.5,16)
ax2.set_xlim(-1,0.5)

ax3.legend()
ax3.set_ylim(27.5,16)
ax3.set_xlim(-1,0.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)


ax1.scatter(uncut['median_f606w']-uncut['median_f814w'],uncut['median_f606w'],
           label='Uncut, Sph',alpha=0.5,color='maroon',zorder=0)
ax1.scatter(old_sig_sph['mean_f606w']-old_sig_sph['mean_f814w'],old_sig_sph['mean_f606w'],
            label='Old Sig, Sph',alpha=0.5,color='dodgerblue')

ax2.scatter(uncut['median_f606w']-uncut['median_f814w'],uncut['median_f606w'],
           label='Uncut, Sph',alpha=0.5,color='maroon',zorder=0)
ax2.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')

ax3.scatter(old_sig_sph['mean_f606w']-old_sig_sph['mean_f814w'],old_sig_sph['mean_f606w'],
           label='Old Sig, Sph',alpha=0.5,color='dodgerblue')
ax3.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta',zorder=1)


# ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5,color='dodgerblue')




ax1.legend()
ax1.set_ylim(27.5,16)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606w-F814W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(27.5,16)
ax2.set_xlim(-1,0.5)

ax3.legend()
ax3.set_ylim(27.5,16)
ax3.set_xlim(-1,0.5)

plt.show()

# %%
# fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

# ax1.scatter(old_sig_sph['mean_f606w']-old_sig_sph['mean_f814w'],old_sig_sph['mean_f606w'],
#            label='Old Sig, Sph',alpha=0.5,color='orange')
# ax1.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
#            label='Old Sig, Pix',alpha=0.5,color='seagreen')

# ax2.scatter(new_sig_sph['mean_f606w']-new_sig_sph['mean_f814w'],new_sig_sph['mean_f606w'],
#            label='New Sig, Sph',alpha=0.5,color='red')
# ax2.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
#            label='New Sig, Pix',alpha=0.5,color='dodgerblue')

# ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF',alpha=0.5,color='blue')
# # ax3.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
# #            label='Old Sig, Pix',alpha=0.5,color='goldenrod')
# # ax3.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
# #            label='New Sig, Pix',alpha=0.5,color='magenta',zorder=0)

# ax1.legend()
# ax1.set_ylim(27.5,16)
# ax1.set_xlim(-1,0.5)
# ax1.set_ylabel('F606w-F814W')

# ax2.legend()
# ax2.set_ylim(27.5,16)
# ax2.set_xlim(-1,0.5)
# ax2.set_xlabel('F606W')

# ax3.legend()
# ax3.set_ylim(27.5,16)
# ax3.set_xlim(-1,0.5)

# plt.show()

# %%
ax1.scatter(new_sig_sph['mean_f606w']-new_sig_sph['mean_f814w'],new_sig_sph['mean_f606w'],
           label='New Sig, Sph',alpha=0.5)

# %%
ax1.scatter(old_sig_pix['mean_f606w']-old_sig_pix['mean_f814w'],old_sig_pix['mean_f606w'],
           label='Old Sig, Pix',alpha=0.5)

ax1.scatter(new_sig_pix['mean_f606w']-new_sig_pix['mean_f814w'],new_sig_pix['mean_f606w'],
           label='New Sig, Pix',alpha=0.5)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax1.scatter(old_sig_sph['mean_f606w'],old_sig_sph['stdev_f606w'],
           label='Old Sig, Sph',alpha=0.5,color='orange')

ax2.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax2.scatter(new_sig_sph['mean_f606w'],new_sig_sph['stdev_f606w'],
           label='New Sig, Sph',alpha=0.5,color='red')

ax3.scatter(old_sig_sph['mean_f606w'],old_sig_sph['stdev_f606w'],
           label='Old Sig, Sph',alpha=0.5,color='orange')

ax3.scatter(new_sig_sph['mean_f606w'],new_sig_sph['stdev_f606w'],
           label='New Sig, Sph',alpha=0.5,color='red')

ax1.legend()
ax1.set_ylim(0,0.5)
ax1.set_xlim(17,27.5)
ax1.set_ylabel('STDEV F606W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(0,0.5)
ax2.set_xlim(17,27.5)

ax3.legend()
ax3.set_ylim(0,0.5)
ax3.set_xlim(17,27.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax1.scatter(old_sig_pix['mean_f606w'],old_sig_pix['stdev_f606w'],
           label='Old Sig, 6 Pix',alpha=0.5,color='goldenrod')

ax2.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax2.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')

ax3.scatter(old_sig_pix['mean_f606w'],old_sig_pix['stdev_f606w'],
           label='Old Sig, 6 Pix',alpha=0.5,color='goldenrod')

ax3.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, 6 Pix',alpha=0.5,color='magenta')

ax1.legend()
ax1.set_ylim(0,0.5)
ax1.set_xlim(17,27.5)
ax1.set_ylabel('STDEV F606W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(0,0.5)
ax2.set_xlim(17,27.5)

ax3.legend()
ax3.set_ylim(0,0.5)
ax3.set_xlim(17,27.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(old_sig_sph['mean_f606w'],old_sig_sph['stdev_f606w'],
           label='Old Sig, Sph',alpha=0.4,color='orange',zorder=1)
ax1.scatter(old_sig_pix['mean_f606w'],old_sig_pix['stdev_f606w'],
           label='Old Sig, Pix',alpha=0.4,color='seagreen',zorder=0)

# ax2.scatter(new_sig_sph['mean_f606w'],new_sig_sph['stdev_f606w'],
#            label='New Sig, Sph',alpha=0.4,color='dodgerblue',zorder=1)
ax2.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, Pix',alpha=0.4,color='magenta',zorder=0)


ax3.scatter(old_sig_sph['mean_f606w'],old_sig_sph['stdev_f606w'],
           label='Old Sig, Sph',alpha=0.4,color='orange',zorder=1)
ax3.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, Pix',alpha=0.4,color='magenta',zorder=0)

ax1.legend()
ax1.set_ylim(0,0.5)
ax1.set_xlim(17,27.5)
ax1.set_ylabel('STDEV F606W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(0,0.5)
ax2.set_xlim(17,27.5)

ax3.legend()
ax3.set_ylim(0,0.5)
ax3.set_xlim(17,27.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax1.scatter(new_new['mean_f606w'],new_new['stdev_f606w'],
           label='New Sig, 2 Pix',alpha=0.4,color='seagreen',zorder=1)


ax2.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, 6 Pix',alpha=0.4,color='magenta',zorder=0)
ax2.scatter(new_new['mean_f606w'],new_new['stdev_f606w'],
           label='New Sig, 2 Pix',alpha=0.4,color='seagreen',zorder=1)

ax3.scatter(old_sig_pix['mean_f606w'],old_sig_pix['stdev_f606w'],
           label='Old Sig, 6 Pix',alpha=0.4,color='orange',zorder=0)
ax3.scatter(new_new['mean_f606w'],new_new['stdev_f606w'],
           label='New Sig, 2 Pix',alpha=0.4,color='seagreen',zorder=1)

ax1.legend()
ax1.set_ylim(0,0.5)
ax1.set_xlim(17,27.5)
ax1.set_ylabel('STDEV F606W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(0,0.5)
ax2.set_xlim(17,27.5)

ax3.legend()
ax3.set_ylim(0,0.5)
ax3.set_xlim(17,27.5)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True)

ax1.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax1.scatter(old_sig_sph['mean_f606w'],old_sig_sph['stdev_f606w'],
           label='Old Sig, Sph',alpha=0.4,color='orange',zorder=1)


ax2.scatter(psf['m606c'],psf['s606'],label='PSF',alpha=0.5)
ax2.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, Pix',alpha=0.4,color='magenta',zorder=1)


ax3.scatter(old_sig_sph['mean_f606w'],old_sig_sph['stdev_f606w'],
           label='Old Sig, Sph',alpha=0.4,color='orange',zorder=0)
ax3.scatter(new_sig_pix['mean_f606w'],new_sig_pix['stdev_f606w'],
           label='New Sig, Pix',alpha=0.4,color='magenta',zorder=1)

ax1.legend()
ax1.set_ylim(0,0.5)
ax1.set_xlim(17,27.5)
ax1.set_ylabel('STDEV F606W')
ax2.set_xlabel('F606W')
ax2.legend()
ax2.set_ylim(0,0.5)
ax2.set_xlim(17,27.5)

ax3.legend()
ax3.set_ylim(0,0.5)
ax3.set_xlim(17,27.5)

plt.show()
