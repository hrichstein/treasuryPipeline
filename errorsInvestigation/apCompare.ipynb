# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
plt.rcParams['axes.grid'] = True

# %%
# My aperture photometry
han_ap_nm = np.genfromtxt('han_ap_nm612.dat',names=True)
han_ap_ma = np.genfromtxt('han_ap_match612.dat',names=True)
han_ap_al = np.genfromtxt('han_ap_all612.dat',names=True)

# Mattia's aperture photometry
mat_ap_nm = np.genfromtxt('mat_ap_nm612.dat',names=True)
mat_ap_ma = np.genfromtxt('mat_ap_match612.dat',names=True)
mat_ap_al = np.genfromtxt('mat_ap_all612.dat',names=True)

# Mattia's PSF photometry - has RA and DEC too
mat_psf_nm = np.genfromtxt('mat_psf_nm612.dat',names=True)
mat_psf_ma = np.genfromtxt('mat_psf_match612.dat',names=True)
mat_psf_al = np.genfromtxt('mat_psf_all612.dat',names=True)

# %%
print(len(han_ap_nm))
print(len(han_ap_ma))
print(len(han_ap_al))

print(len(mat_ap_nm))
print(len(mat_ap_ma))
print(len(mat_ap_al))

print(len(mat_psf_nm))
print(len(mat_psf_ma))
print(len(mat_psf_al))
# Out:
# 291
# 450
# 753
# 179
# 3237
# 4594
# 209
# 3127
# 3694

# %%
mag_bin = np.arange(20,28,0.5)

plt.hist(mat_psf_nm['m606c'],bins=mag_bin,density=True,label='Matt PSF NM')
plt.hist(mat_psf_ma['m606c'],bins=mag_bin,density=True,label='Matt PSF MA')

plt.hist(mat_ap_nm['m606c'],bins=mag_bin,density=True,label='Matt Ap NM',alpha=0.5)
plt.hist(mat_ap_ma['m606c'],bins=mag_bin,density=True,label='Matt Ap MA',alpha=0.5)

plt.hist(han_ap_nm['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap NM',alpha=0.5)
plt.hist(han_ap_ma['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap MA',alpha=0.5)



plt.legend()
plt.show()

# %%
plt.hist(mat_psf_nm['m606c'],bins=mag_bin,density=True,label='Matt PSF NM')
plt.hist(mat_psf_ma['m606c'],bins=mag_bin,density=True,label='Matt PSF MA',alpha=0.6)

plt.legend()
plt.show()

# %%
plt.hist(mat_psf_nm['m606c'],bins=mag_bin,density=True,label='Matt PSF NM')
# plt.hist(mat_psf_ma['m606c'],bins=mag_bin,density=True,label='Matt PSF MA')

plt.hist(mat_ap_nm['m606c'],bins=mag_bin,density=True,label='Matt Ap NM',alpha=0.6)
# plt.hist(mat_ap_ma['m606c'],bins=mag_bin,density=True,label='Matt Ap MA')

plt.hist(han_ap_nm['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap NM',alpha=0.7)
# plt.hist(han_ap_ma['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap MA')

plt.legend()
plt.show()

# %%
# plt.hist(mat_psf_nm['m606c'],bins=mag_bin,density=True,label='Matt PSF NM')
plt.hist(mat_psf_ma['m606c'],bins=mag_bin,density=True,label='Matt PSF MA')

# plt.hist(mat_ap_nm['m606c'],bins=mag_bin,density=True,label='Matt Ap NM',alpha=0.6)
plt.hist(mat_ap_ma['m606c'],bins=mag_bin,density=True,label='Matt Ap MA',alpha=0.5)

# plt.hist(han_ap_nm['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap NM')
# plt.hist(han_ap_ma['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap MA')

plt.legend()
plt.show()

# %%
# plt.hist(mat_psf_nm['m606c'],bins=mag_bin,density=True,label='Matt PSF NM')
plt.hist(mat_psf_ma['m606c'],bins=mag_bin,density=True,label='Matt PSF MA')

# plt.hist(mat_ap_nm['m606c'],bins=mag_bin,density=True,label='Matt Ap NM',alpha=0.6)
plt.hist(mat_ap_ma['m606c'],bins=mag_bin,density=True,label='Matt Ap MA',alpha=0.5)

# plt.hist(han_ap_nm['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap NM')
plt.hist(han_ap_ma['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap MA',alpha=0.7)

plt.legend()
plt.show()

# %%
# plt.hist(mat_psf_nm['m606c'],bins=mag_bin,density=True,label='Matt PSF NM')
# plt.hist(mat_psf_ma['m606c'],bins=mag_bin,density=True,label='Matt PSF MA')

# plt.hist(mat_ap_nm['m606c'],bins=mag_bin,density=True,label='Matt Ap NM',alpha=0.6)
# plt.hist(mat_ap_ma['m606c'],bins=mag_bin,density=True,label='Matt Ap MA',alpha=0.5)

plt.hist(han_ap_nm['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap NM')
plt.hist(han_ap_ma['mag1_f606w'],bins=mag_bin,density=True,label='Han Ap MA',alpha=0.7)

plt.legend()
plt.show()

# %%
# something in the 24 - 26 region where nonmatching occurs more often

# %%
mat_ap_nm.dtype.names
# Out:
# ('x',
#  'y',
#  'm606c',
#  'm814c',
#  'nstar',
#  'sat606',
#  'sat814',
#  'camera',
#  'm606',
#  's606',
#  'q606',
#  'o606',
#  'f606',
#  'g606',
#  'rxs606',
#  'sky606',
#  'rmssky606',
#  'm814',
#  's814',
#  'q814',
#  'o814',
#  'f814',
#  'g814',
#  'rxs814',
#  'sky814',
#  'rmssky814')

# %%
hac_nm1 = np.array([han_ap_nm['mag1_f606w']\
                          -han_ap_nm['mag1_f814w']])
hac_nm2 = np.array([han_ap_nm['mag2_f606w']\
                          -han_ap_nm['mag2_f814w']])
hac_nm3 = np.array([han_ap_nm['mag3_f606w']\
                          -han_ap_nm['mag3_f814w']])
hac_nm4 = np.array([han_ap_nm['mag4_f606w']\
                          -han_ap_nm['mag4_f814w']])

# %%
hac_ma1 = np.array([han_ap_ma['mag1_f606w']\
                          -han_ap_ma['mag1_f814w']])
hac_ma2 = np.array([han_ap_ma['mag2_f606w']\
                          -han_ap_ma['mag2_f814w']])
hac_ma3 = np.array([han_ap_ma['mag3_f606w']\
                          -han_ap_ma['mag3_f814w']])
hac_ma4 = np.array([han_ap_ma['mag4_f606w']\
                          -han_ap_ma['mag4_f814w']])

# %%
mac_nm = np.array([mat_ap_nm['m606c'] - mat_ap_nm['m814c']])
mac_ma = np.array([mat_ap_ma['m606c'] - mat_ap_ma['m814c']])

mac_nm_psf = np.array([mat_psf_nm['m606c'] - mat_psf_nm['m814c']])
mac_ma_psf = np.array([mat_psf_ma['m606c'] - mat_psf_ma['m814c']])

# %%
# comparison of stars in non-matching error region

fig, ax = plt.subplots()

ax.scatter(hac_nm1,han_ap_nm['mag1_f606w'],s=3,label='Han')
ax.scatter(mac_nm,mat_ap_nm['m606c'],s=3,label='Matt Ap')
ax.scatter(mac_nm_psf,mat_psf_nm['m606c'],s=3,label='Matt PSF')

ax.set_xlabel('F606W')
ax.set_ylabel('F814W-F606W')
ax.set_title('Non-Matching Error Clouds')
ax.set_ylim(28,20)
ax.set_xlim(-2,2)

plt.legend()
plt.show()

# %%
# comparison of CMDs of our stars within the matching error range
fig, ax = plt.subplots()

ax.scatter(mac_ma_psf,mat_psf_ma['m606c'],s=3,label='Matt PSF')
ax.scatter(mac_ma,mat_ap_ma['m606c'],s=3,label='Matt Ap')
ax.scatter(hac_ma1,han_ap_ma['mag1_f606w'],s=3,label='Han Ap')

ax.set_ylim(28,20)
ax.set_xlim(-2,2)
ax.set_xlabel('F606W')
ax.set_ylabel('F814W-F606W')
ax.set_title('Matching Error Region')
plt.legend()
plt.show()

# %%
# comparison of CMDs of our stars within the matching error range
fig, ax = plt.subplots()

# ax.scatter(mac_ma_psf,mat_psf_ma['m606c'],s=3,label='Matt PSF')
ax.scatter(mac_ma,mat_ap_ma['m606c'],s=3,label='Matt Ap',color='blue')
ax.scatter(hac_ma1,han_ap_ma['mag1_f606w'],s=3,label='Han Ap',color='orange')

ax.set_ylim(25,22)
ax.set_xlim(-1,0)
ax.set_xlabel('F606W')
ax.set_ylabel('F814W-F606W')
ax.set_title('Matching Error Region - Ap Phot Comparison')
plt.legend()
plt.show()

# %%
# comparison of CMDs of our stars within the matching error range
fig, ax = plt.subplots()


ax.scatter(mac_ma_psf,mat_psf_ma['m606c'],s=3,label='Matt PSF',color='magenta')
ax.scatter(mac_ma,mat_ap_ma['m606c'],s=3,label='Matt Ap',color='blue')
# ax.scatter(hac_ma1,han_ap_ma['mag1_f606w'],s=3,label='Han Ap')

ax.set_ylim(25,22)
ax.set_xlim(-1,0)
ax.set_xlabel('F606W')
ax.set_ylabel('F814W-F606W')
ax.set_title('Matching Error Region - Matt PSF and Ap')
plt.legend()
plt.show()

# %%
# comparison of CMDs of our stars within the matching error range
fig, ax = plt.subplots()


ax.scatter(mac_ma_psf,mat_psf_ma['m606c'],s=3,label='Matt PSF',color='magenta')
# ax.scatter(mac_ma,mat_ap_ma['m606c'],s=3,label='Matt Ap')
ax.scatter(hac_ma1,han_ap_ma['mag1_f606w'],s=3,label='Han Ap',color='orange')

ax.set_ylim(25,22)
ax.set_xlim(-1,0)
ax.set_xlabel('F606W')
ax.set_ylabel('F814W-F606W')
ax.set_title('Matching Error Region - Matt PSF, Han Ap')
plt.legend()
plt.show()

# %%
# comparison of CMDs of our stars within the matching error range
fig, ax = plt.subplots()

ax.scatter(mac_ma_psf,mat_psf_ma['m606c'],s=3,label='Matt PSF')
ax.scatter(mac_ma,mat_ap_ma['m606c'],s=3,label='Matt Ap',color='blue')
ax.scatter(hac_ma1,han_ap_ma['mag1_f606w'],s=3,label='Han Ap',color='orange')

ax.set_ylim(25,22)
ax.set_xlim(-1,0)
ax.set_xlabel('F606W')
ax.set_ylabel('F814W-F606W')
ax.set_title('Matching Error Region - Ap Phot Comparison')
plt.legend()
plt.show()

# %%
data = han_ap_nm['mag1_f606w']
bins = np.arange(20, 28, 0.5)
digitized = np.digitize(data, bins)
bin_means_han = [data[digitized == i].mean() for i in range(1, len(bins))]
# Out:
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice.
#   after removing the cwd from sys.path.

# %%
data1a = han_ap_ma['mag1_f606w']
digitized = np.digitize(data1a, bins)
bin_means_han_ma = [data1a[digitized == i].mean() for i in range(1, len(bins))]

# %%
data2 = mat_ap_nm['m606c']
digitized2 = np.digitize(data2, bins)
bin_means_mat = [data2[digitized2 == i].mean() \
                 for i in range(1, len(bins))]
# Out:
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice.
#   after removing the cwd from sys.path.

# %%
data2a = mat_ap_nm['m606c']
digitized2a = np.digitize(data2a, bins)
bin_means_mat_ma = [data2a[digitized2a == i].mean() \
                 for i in range(1, len(bins))]
# Out:
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice.
#   after removing the cwd from sys.path.

# %%
data3 = mat_psf_nm['m606c']
digitized3 = np.digitize(data3, bins)
bin_means_psf = [data3[digitized3 == i].mean() \
                 for i in range(1, len(bins))]
# Out:
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice.
#   after removing the cwd from sys.path.

# %%
data3a = mat_psf_ma['m606c']
digitized3a = np.digitize(data3a, bins)
bin_means_psf_ma = [data3a[digitized3a == i].mean() \
                 for i in range(1, len(bins))]
# Out:
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice.
#   after removing the cwd from sys.path.

# %%
# data = han_ap_nm['mag1_f814w']
# bins = np.arange(20, 28, 0.5)
# digitized = np.digitize(data, bins)
# bin_means_han_814 = [data[digitized == i].mean() for i in range(1, len(bins))]

# data1a = han_ap_ma['mag1_f814w']
# digitized = np.digitize(data1a, bins)
# bin_means_han_ma_814 = [data1a[digitized == i].mean() for i in range(1, len(bins))]

# data2 = mat_ap_nm['m814c']
# digitized2 = np.digitize(data2, bins)
# bin_means_mat_814 = [data2[digitized2 == i].mean() \
#                  for i in range(1, len(bins))]

# data2a = mat_ap_nm['m814c']
# digitized2a = np.digitize(data2a, bins)
# bin_means_mat_ma_814 = [data2a[digitized2a == i].mean() \
#                  for i in range(1, len(bins))]

# data3 = mat_psf_nm['m814c']
# digitized3 = np.digitize(data3, bins)
# bin_means_psf_814 = [data3[digitized3 == i].mean() \
#                  for i in range(1, len(bins))]

# data3a = mat_psf_ma['m814c']
# digitized3a = np.digitize(data3a, bins)
# bin_means_psf_ma_814 = [data3a[digitized3a == i].mean() \
#                  for i in range(1, len(bins))]

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(14,4),sharey=True)

ax1.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
          label='Han_Ap-Matt_Ap NM')
ax1.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
          label='Matt_PSF-Matt_Ap NM')

ax1.set_xlabel('F606W')
ax1.set_ylabel('Difference in Mag')
ax1.legend()

ax2.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
          label='Han_Ap-Matt_Ap MA',marker='+')
ax2.scatter(bin_means_mat_ma,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
          label='Matt_PSF-Matt_Ap MA',marker='+')


ax2.set_xlabel('F606W')
ax2.set_ylabel('Difference in Mag')
ax2.legend()

plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
          label='Han_Ap-Matt_Ap NM')
ax.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
          label='Matt_PSF-Matt_Ap NM')
ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
          label='Han_Ap-Matt_Ap MA',marker='+')
ax.scatter(bin_means_mat_ma,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
          label='Matt_PSF-Matt_Ap MA',marker='+')

ax.set_xlabel('F606W')
ax.set_ylabel('Difference in Mag')
ax.legend()


plt.grid(True)
plt.show()

# %%
# fig, ax = plt.subplots(figsize=(12,6))

# # ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
# #           label='Han_Ap-Matt_Ap NM')
# ax.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
#           label='Matt_PSF-Matt_Ap NM')
# ax.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han),\
#           label='Matt_PSF-Han_Ap NM')
# ax.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han_ma),\
#           label='Matt_PSF-Han_Ap NM')
# # ax.scatter(bin_means_mat,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
# #           label='Han_Ap-Matt_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
#           label='Matt_PSF-Matt_Ap MA',marker='+')

# ax.set_xlabel('F606W')
# ax.set_ylabel('Difference in Mag')
# ax.legend()




# plt.grid(True)
# plt.show()

# %%
# fig, ax = plt.subplots()

# ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
#           label='Han_Ap-Matt_Ap MA',marker='+')
# ax.scatter(bin_means_mat_ma,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
#           label='Matt_PSF-Matt_Ap MA',marker='+')


# ax.set_xlabel('F606W')
# ax.set_ylabel('Difference in Mag')
# ax.legend()

# plt.grid(True)
# plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
          label='Han_Ap-Matt_Ap MA',marker='+')
# ax.scatter(bin_means_mat_ma,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
#           label='Matt_PSF-Matt_Ap vs Matt_Ap MA',marker='+')
ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
          label='Han_Ap-Matt_Ap NM')
# ax.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
#           label='Matt_PSF-Matt_Ap vs Matt_Ap')


ax.set_xlabel('F606W Mag')
ax.set_ylabel('Difference in Mag')
ax.legend()

plt.grid(True)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,6))

# ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap MA',marker='+')
plt.grid(True)
ax1.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
          label='Matt_PSF-Matt_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax1.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
          label='Matt_PSF-Matt_Ap NM')


ax1.set_xlabel('F606W Mag')
ax1.set_ylabel('Difference in Mag')
ax1.legend()


ax2.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_han_ma),\
          label='Matt_PSF-Han_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han),\
          label='Matt_PSF-Han_Ap NM')


ax2.set_xlabel('F606W Mag')
ax2.set_ylabel('Difference in Mag')
ax2.legend()

plt.grid(True)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,6))

# ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap MA',marker='+')
plt.grid(True)
ax1.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
          label='Matt_PSF-Matt_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
          label='Matt_PSF-Matt_Ap NM')


ax1.set_xlabel('F606W Mag')
ax1.set_ylabel('Difference in Mag')



ax1.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_han_ma),\
          label='Matt_PSF-Han_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han),\
          label='Matt_PSF-Han_Ap NM')


ax2.set_xlabel('F606W Mag')
ax2.set_ylabel('Difference in Mag')
ax1.legend()
ax2.legend()

plt.grid(True)
plt.show()

# %%
data = hac_nm1
bins = np.arange(-1, 2, 0.25)
digitized1 = np.digitize(data, bins)
bin_means_han = [data[digitized1 == i].mean() for i in range(1, len(bins))]
# bin_range_han = [np.max(data[digitized == i])-np.min(data[digitized == i]) for i in range(1, len(bins))]

data1a = hac_ma1
digitized1a = np.digitize(data1a, bins)
bin_means_han_ma = [data1a[digitized1a == i].mean() for i in range(1, len(bins))]
# bin_range_han_ma = [np.max(data[digitized == i])-np.min(data[digitized == i]) for i in range(1, len(bins))]

data2 = mac_nm
digitized2 = np.digitize(data2, bins)
bin_means_mat = [data2[digitized2 == i].mean() \
                 for i in range(1, len(bins))]
# bin_range_mat = [np.max(data[digitized == i])-np.min(data[digitized == i]) for i in range(1, len(bins))]

data2a = mac_ma
digitized2a = np.digitize(data2a, bins)
bin_means_mat_ma = [data2a[digitized2a == i].mean() \
                 for i in range(1, len(bins))]
# bin_range_mat_ma = [np.max(data[digitized == i])-np.min(data[digitized == i]) for i in range(1, len(bins))]

data3 = mac_nm_psf
digitized3 = np.digitize(data3, bins)
bin_means_psf = [data3[digitized3 == i].mean() \
                 for i in range(1, len(bins))]
# bin_range_psf = [np.max(data[digitized == i])-np.min(data[digitized == i]) for i in range(1, len(bins))]

data3a = mac_ma_psf
digitized3a = np.digitize(data3a, bins)
bin_means_psf_ma = [data3a[digitized3a == i].mean() \
                 for i in range(1, len(bins))]
# bin_range_psf_ma = [np.max(data[digitized == i])-np.min(data[digitized == i]) for i in range(1, len(bins))]
# Out:
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice.
#   from ipykernel import kernelapp as app
# /Users/hr8jz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: Mean of empty slice.

# %%
col_dif_mat_nm = np.zeros((len(bins)))
for i in range(1,len(bins)):
    col_dif_mat_nm[i]=np.max(data2[digitized2 == i]) - np.min(data2[digitized2 == i])

col_dif_mat_ma = np.zeros((len(bins)))
for i in range(1,len(bins)):
    col_dif_mat_ma[i]=np.max(data2a[digitized3 == i]) - np.min(data2a[digitized2a == i])

col_dif_nm_psf = np.zeros((len(bins)))
for i in range(1,len(bins)):
    col_dif_nm_psf[i]=np.max(data3[digitized3 == i]) - np.min(data3[digitized3 == i])    

col_dif_ma_psf = np.zeros((len(bins)))
for i in range(1,len(bins)):
    col_dif_ma_psf[i]=np.max(data3a[digitized3a == i]) - np.min(data3a[digitized3a == i])

# %%
col_dif_han_nm = np.zeros((len(bins)))
for i in range(1,len(bins)):
    col_dif_mat_nm[i]=np.max(data1[digitized1 == i]) - np.min(data1[digitized1 == i])

col_dif_han_ma = np.zeros((len(bins)))
for i in range(1,len(bins)):
    col_dif_mat_ma[i]=np.max(data1a[digitized1a == i]) - np.min(data1a[digitized1a == i])

# %%
col_dif_test
# Out:
# array([0.    , 0.2491, 0.2479, 0.249 , 0.2483, 0.2466, 0.248 , 0.2438,
#        0.2326, 0.2151, 0.2194, 0.1649])

# %%
bin_means_psf
# Out:
# [-0.8987000000000016,
#  -0.5910258064516131,
#  -0.37659285714285706,
#  -0.13536399999999982,
#  0.10030294117647057,
#  0.34054285714285776,
#  0.6169999999999997,
#  0.8558000000000003,
#  1.140975000000001,
#  nan,
#  1.6633999999999993]

# %%
for ii in range(1,len(bins)):

# %%
mean_col_bins = np.arange(-1,2,0.25)

# %%
plt.clf()

# %%
mac_ma_psf[0]
# Out:
# array([-0.6514,  0.2643, -0.2392, ...,  9.9824, -0.0483, -0.5717])

# %%
plt.hist(mac_ma_psf[0],bins=mean_col_bins,alpha=0.5,label='MA') 
plt.hist(mac_nm_psf[0],bins=mean_col_bins,alpha=0.5,label='NM') 


plt.legend()
plt.show()

# %%
plt.hist(mac_ma[0],bins=mean_col_bins,alpha=0.5,label='MA')
plt.hist(mac_nm[0],bins=mean_col_bins,alpha=0.5,label='NM') 

plt.legend()
plt.show()

# %%
plt.hist(hac_nm1[0],bins=mean_col_bins,alpha=0.5,label='NM') 
plt.hist(hac_ma1[0],bins=mean_col_bins,alpha=0.5,label='MA')

# plt.title("Mean Dist Diffs") 
plt.legend()
plt.show()

# %%
plt.hist(mac_ma[0],bins=mean_col_bins,label='Matt Ap MA',density=True,alpha=0.5)
plt.hist(mac_ma_psf[0],bins=mean_col_bins,label='PSF MA',density=True,alpha=0.5) 

# plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.hist(hac_ma1[0],bins=mean_col_bins,label='Han MA',density=True,alpha=0.5)
plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM',density=True,alpha=0.5) 

plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.5) 
plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
plt.hist(mac_ma[0],bins=mean_col_bins,label='Matt Ap MA',density=True,alpha=0.5)
plt.hist(mac_ma_psf[0],bins=mean_col_bins,label='PSF MA',density=True,alpha=0.5) 

plt.legend()
plt.show()

# %%
plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.5) 
plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
plt.hist(hac_ma1[0],bins=mean_col_bins,label='Han MA',density=True,alpha=0.5)
plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM',density=True,alpha=0.5) 

# plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.5) 
# plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
plt.hist(hac_ma1[0],bins=mean_col_bins,label='Han MA',density=True)
# plt.hist(hac_ma2[0],bins=mean_col_bins,label='Han MA',density=True)
# plt.hist(hac_ma3[0],bins=mean_col_bins,label='Han MA',density=True)
# plt.hist(hac_ma4[0],bins=mean_col_bins,label='Han MA',density=True)
# plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM',density=True,alpha=0.5) 

plt.hist(mac_ma_psf[0],bins=mean_col_bins,label='PSF MA',density=True,alpha=0.8) 
plt.hist(mac_ma[0],bins=mean_col_bins,label='Matt Ap MA',density=True,alpha=0.3)
# plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.5) 
# plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
plt.hist(hac_ma1[0],bins=mean_col_bins,label='Han MA1',density=True,alpha=0.6)
plt.hist(hac_ma2[0],bins=mean_col_bins,label='Han MA2',density=True,alpha=0.6)
plt.hist(hac_ma3[0],bins=mean_col_bins,label='Han MA3',density=True,alpha=0.6)
plt.hist(hac_ma4[0],bins=mean_col_bins,label='Han MA4',density=True,alpha=0.6)
# plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM',density=True,alpha=0.5) 

# plt.hist(mac_ma_psf[0],bins=mean_col_bins,label='PSF MA',density=True,alpha=0.8) 
# plt.hist(mac_ma[0],bins=mean_col_bins,label='Matt Ap MA',density=True,alpha=0.3)
# plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.5) 
# plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM1',density=True,alpha=0.6)
plt.hist(hac_nm2[0],bins=mean_col_bins,label='Han NM2',density=True,alpha=0.6)
plt.hist(hac_nm3[0],bins=mean_col_bins,label='Han NM3',density=True,alpha=0.6)
plt.hist(hac_nm4[0],bins=mean_col_bins,label='Han NM4',density=True,alpha=0.6)
# plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM',density=True,alpha=0.5) 

# plt.hist(mac_ma_psf[0],bins=mean_col_bins,label='PSF MA',density=True,alpha=0.8) 
# plt.hist(mac_ma[0],bins=mean_col_bins,label='Matt Ap MA',density=True,alpha=0.3)
# plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.5) 
# plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
# plt.hist(hac_ma1[0],bins=mean_col_bins,label='Han MA',density=True)
plt.hist(hac_nm1[0],bins=mean_col_bins,label='Han NM',density=True) 

# plt.hist(mac_ma_psf[0],bins=mean_col_bins,label='PSF MA',density=True,alpha=0.8) 
# plt.hist(mac_ma[0],bins=mean_col_bins,label='Matt Ap MA',density=True,alpha=0.3)
plt.hist(mac_nm_psf[0],bins=mean_col_bins,label='PSF NM',density=True,alpha=0.7)
plt.hist(mac_nm[0],bins=mean_col_bins,label='Matt Ap NM',density=True,alpha=0.5)
plt.legend()
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,6))

# ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap MA',marker='+')
plt.grid(True)
ax1.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
          label='Matt_PSF-Matt_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax1.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
          label='Matt_PSF-Matt_Ap NM')


ax1.set_xlabel('Mean Matt Ap Mag')
ax1.set_ylabel('Difference in Mag')
ax1.legend()


ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han_ma),\
          label='Matt_PSF-Han_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han),\
          label='Matt_PSF-Han_Ap NM')


ax2.set_xlabel('F606W-F814W')
ax2.set_ylabel('Difference in Mag')
ax2.legend()

plt.grid(True)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,6),sharey=True)

# ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap MA',marker='+')
plt.grid(True)
ax1.scatter(bin_means_mat_ma,np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma),\
          label='Matt_PSF-Matt_Ap MA',marker='+')
ax1.scatter(bin_means_mat_ma,np.array(bin_means_psf)-np.array(bin_means_han_ma),\
          label='Matt_PSF-Han_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')


ax1.set_xlabel('F606W-F814W')
ax1.set_ylabel('Difference in Col')
ax1.legend()



# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han),\
          label='Matt_PSF-Han_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_mat),\
          label='Matt_PSF-Matt_Ap NM')


ax2.set_xlabel('F606W-F814W')
ax2.set_ylabel('Difference in Col')
ax2.legend()

plt.grid(True)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,6),sharey=True)

# ax.scatter(bin_means_mat_ma,np.array(bin_means_han_ma)-np.array(bin_means_mat_ma),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap MA',marker='+')
plt.grid(True)
ax1.scatter(bin_means_mat,np.array(bin_means_mat_ma)-np.array(bin_means_han_ma),\
          label='Matt_Ap-Han_Ap MA',marker='+')
ax1.scatter(bin_means_mat,np.array(bin_means_psf_ma)-np.array(bin_means_han_ma),\
          label='Matt_PSF-Han_Ap MA',marker='+')
# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')


ax1.set_xlabel('F606W-F814W')
ax1.set_ylabel('Difference in Col')
ax1.legend()



# ax.scatter(bin_means_mat,np.array(bin_means_han)-np.array(bin_means_mat),\
#           label='Han_Ap-Matt_Ap vs Matt_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_mat)-np.array(bin_means_han),\
          label='Matt_Ap-Han_Ap NM')
ax2.scatter(bin_means_mat,np.array(bin_means_psf)-np.array(bin_means_han),\
          label='Matt_PSF-Han_Ap NM')


ax2.set_xlabel('F606W-F814W')
ax2.set_ylabel('Difference in Col')
ax2.legend()

plt.grid(True)
plt.show()

# %%
# print(np.array(bin_means_psf_ma)-np.array(bin_means_mat_ma))
