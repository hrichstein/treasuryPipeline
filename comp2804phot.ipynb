# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
new_phot = np.genfromtxt('hor1dir2804/HORI_comb2804.dat',names=True)

# %%
orig_cr = np.genfromtxt('drc_flc_CR/HORI_pix_2503_comb.dat',names=True)

# %%
no_cr_rem = np.genfromtxt('hor1dir6pix/HORI_pix_2212_d6_dist.dat',names=True)

# %%
psf = np.genfromtxt('elena_cats/HOROLOGIUM_CF.1.PSF.CAT',names=True)

# %%
drc = np.genfromtxt('/Users/hr8jz/Box Sync/Research/source_lists/june13/HOROLOGIUM-I_sfErr.dat',names=True)

# %%
ra_dec_flc = np.genfromtxt('magsWerrs0811/HORI_final_0612.dat',names=True)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,7),sharex=True,sharey=True)

ax1.scatter(new_phot['mean_f606w']-new_phot['mean_f814w'],new_phot['mean_f606w'],s=5,label='New')
ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax2.scatter(orig_cr['mean_f606w']-orig_cr['mean_f814w'],orig_cr['mean_f606w'],s=5,label='Orig CR')
ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax3.scatter(no_cr_rem['mean_f606w']-no_cr_rem['mean_f814w'],no_cr_rem['mean_f606w'],s=5,label='Orig Pix')
ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax1.set_ylim(28,18)
ax1.set_xlim(-1.5,1)

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,7),sharex=True,sharey=True)

ax1.scatter(new_phot['mean_f606w']-new_phot['mean_f814w']+0.05,new_phot['mean_f606w'],s=5,label='New+0.5 Color')
ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax2.scatter(orig_cr['mean_f606w']-orig_cr['mean_f814w'],orig_cr['mean_f606w'],s=5,label='Orig CR')
ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax3.scatter(no_cr_rem['mean_f606w']-no_cr_rem['mean_f814w'],no_cr_rem['mean_f606w'],s=5,label='Orig Pix')
ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax1.set_ylim(28,18)
ax1.set_xlim(-1.5,1)

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,7),sharex=True,sharey=True)

ax1.scatter(new_phot['mean_f606w']-new_phot['mean_f814w'],new_phot['mean_f606w'],s=5,label='New')
ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')
ax1.set_ylabel('F606W')

ax2.scatter(new_phot['mean_f606w']-new_phot['mean_f814w']+0.05,new_phot['mean_f606w'],s=5,label='New+0.05 Color')
ax2.scatter(orig_cr['mean_f606w']-orig_cr['mean_f814w'],orig_cr['mean_f606w'],s=5,label='Orig CR')
ax2.set_xlabel('F606W - F814W')
# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax3.scatter(new_phot['mean_f606w']-new_phot['mean_f814w'],new_phot['mean_f606w'],s=5,label='New')
ax3.scatter(no_cr_rem['mean_f606w']-no_cr_rem['mean_f814w'],no_cr_rem['mean_f606w'],s=5,label='Orig Pix')
# ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax1.set_ylim(28,18)
ax1.set_xlim(-1.5,0.99)

ax1.legend()
ax2.legend()
ax3.legend()

plt.subplots_adjust(wspace=0)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,7),sharex=True,sharey=True)

ax1.scatter(new_phot['mean_f606w']-new_phot['mean_f814w'],new_phot['mean_f814w'],s=5,label='New')
ax1.scatter(psf['m606c']-psf['m814c'],psf['m814c'],s=5,label='PSF')
ax1.set_ylabel('F814W')

ax2.scatter(new_phot['mean_f606w']-new_phot['mean_f814w']+0.05,new_phot['mean_f606w'],s=5,label='New+0.05 Color')
ax2.scatter(orig_cr['mean_f606w']-orig_cr['mean_f814w'],orig_cr['mean_f814w'],s=5,label='Orig CR')
ax2.set_xlabel('F606W - F814W')
# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax3.scatter(new_phot['mean_f606w']-new_phot['mean_f814w'],new_phot['mean_f606w'],s=5,label='New')
ax3.scatter(no_cr_rem['mean_f606w']-no_cr_rem['mean_f814w'],no_cr_rem['mean_f814w'],s=5,label='Orig Pix')
# ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax1.set_ylim(28,18)
ax1.set_xlim(-1.5,0.99)

ax1.legend()
ax2.legend()
ax3.legend()

plt.subplots_adjust(wspace=0)

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,7),sharex=True,sharey=True)

ax1.scatter(new_phot['mean_f606w']-new_phot['mean_f814w']+0.05,new_phot['mean_f606w'],s=5,label='New+0.5 Color')
ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')
ax1.set_ylabel('F606W')

ax2.scatter(new_phot['mean_f606w']-new_phot['mean_f814w']+0.05,new_phot['mean_f606w'],s=5,label='New+0.5 Color')
ax2.scatter(drc['magRaw_v']-drc['magRaw_i']+0.05,drc['magRaw_v'],s=5,label='DRC')
# ax2.scatter(orig_cr['mean_f606w']-orig_cr['mean_f814w'],orig_cr['mean_f606w'],s=5,label='Orig CR')
ax2.set_xlabel('F606W - F814W')
# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax3.scatter(new_phot['mean_f606w']-new_phot['mean_f814w']+0.05,new_phot['mean_f606w'],s=5,label='New+0.5 Color')
ax3.scatter(ra_dec_flc['median_f606w']-ra_dec_flc['median_f814w'],ra_dec_flc['median_f606w'],s=5,label='SphMatch')
# ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],s=5,label='PSF')

ax1.set_ylim(28,18)
ax1.set_xlim(-1.5,0.99)

ax1.legend()
ax2.legend()
ax3.legend()

plt.subplots_adjust(wspace=0)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5))

ax.scatter(no_cr_rem['mean_f606w'],no_cr_rem['stdev_f606w'],label= 'Orig Pix',s=5)
ax.scatter(new_phot['mean_f606w'],new_phot['stdev_f606w'], label = 'New',s=5)

ax.set_ylim(0,0.2)
ax.set_xlim(18,28)
ax.legend()

ax.set_ylabel('F606W Err')
ax.set_xlabel('F606W')

plt.show()
