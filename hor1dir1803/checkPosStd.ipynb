# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'dir2403/HOR-I-cut-std_pix_matched_F606W.dat'
file2 = 'HOR-I-cut-std_pix_matched_F606W.dat'
file0 = 'HOR-I_refStars_F606W.dat'

# %%
data = np.genfromtxt(file,names=True)

# %%
data2 = np.genfromtxt(file2,names=True)

# %%
data3 = np.genfromtxt(file0,names=True)

# %%
fig, ax = plt.subplots()

# ax.scatter(data2['xt_1'],data2['yt_1'],label='Trans1.2')
# ax.scatter(data['xr_1'],data['yr_1'],label='Raw')
ax.scatter(data['xt_1'],data['yt_1'],label='Trans1',alpha=0.5)
ax.scatter(data['xt_2'],data['yt_2'],label='Trans2',alpha=0.5)
ax.scatter(data['xt_3'],data['yt_3'],label='Trans3',alpha=0.5)
ax.scatter(data['xt_4'],data['yt_4'],label='Trans4',alpha=0.5)

ax.set_xlim(1000,2000)
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# ax.scatter(data32['xt_1'],data32['yt_1'],label='Trans1.2')
# ax.scatter(data3['xr_1'],data3['yr_1'],label='Raw')
ax.scatter(data3['xt_1'],data3['yt_1'],label='Trans1',alpha=0.5)
ax.scatter(data3['xt_2'],data3['yt_2'],label='Trans2',alpha=0.5)
ax.scatter(data3['xt_3'],data3['yt_3'],label='Trans3',alpha=0.5)
ax.scatter(data3['xt_4'],data3['yt_4'],label='Trans4',alpha=0.5)

# ax.set_xlim(1000,2000)
ax.legend()
plt.show()

# %%
# After linear
print(np.min(data['pos_std']))
print(np.max(data['pos_std']))
print(np.mean(data['pos_std']))
print(np.median(data['pos_std']))
# Out:
# 0.82275
# 3.64351
# 2.1951918287937744
# 2.3431699999999998

# %%
# Before linear
print(np.min(data2['pos_std']))
print(np.max(data2['pos_std']))
print(np.mean(data2['pos_std']))
print(np.median(data2['pos_std']))
# Out:
# 0.0224
# 3.30875
# 0.42398536676646703
# 0.27019499999999996

# %%
# Just Offset
print(np.min(data3['pos_std']))
print(np.max(data3['pos_std']))
print(np.mean(data3['pos_std']))
print(np.median(data3['pos_std']))
# Out:
# 0.03871
# 0.09929
# 0.07164571428571428
# 0.0748

# %%
plt.hist(data['pos_std'])
# Out:
# (array([  2.,  10.,  76., 119.,  24.,  99., 163.,  17.,   2.,   2.]),
#  array([0.82275 , 1.104826, 1.386902, 1.668978, 1.951054, 2.23313 ,
#         2.515206, 2.797282, 3.079358, 3.361434, 3.64351 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data2['pos_std'])
# Out:
# (array([833., 304.,  95.,  35.,  18.,  19.,  11.,   9.,   6.,   6.]),
#  array([0.0224  , 0.351035, 0.67967 , 1.008305, 1.33694 , 1.665575,
#         1.99421 , 2.322845, 2.65148 , 2.980115, 3.30875 ]),
#  <a list of 10 Patch objects>)
