# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
flc_data_606 = np.genfromtxt('mags0811/HOR-I-xy-std_sph_matched_F606W.dat',names=True)
flc_data_814 = np.genfromtxt('mags0811/HOR-I-xy-std_sph_matched_F814W.dat',names=True)

# %%
pix_d6 = np.genfromtxt('hor1dir3/HORI_pix_2212.dat',names=True)

# %%
drc_data = np.genfromtxt('/Users/hr8jz/Box Sync/Research/source_lists/june13/HOROLOGIUM-I_sfErr.dat',names=True)

# %%
matt_aper = np.genfromtxt('elena_cats/HOROLOGIUM_CF.2.APER.CAT',names=True)
matt_psf = np.genfromtxt('elena_cats/HOROLOGIUM_CF.1.PSF.CAT',names=True)

# %%
len(matt_aper[matt_aper['m606c']<28])
# Out:
# 3144

# %%
len(matt_psf[matt_psf['m606c']<28])
# Out:
# 3427

# %%
len(flc_data_606[flc_data_606['median']<28])
# Out:
# 765

# %%
len(drc_data[drc_data['magRaw_v']<28])
# Out:
# 1528

# %%
fig,ax = plt.subplots(figsize=(8,10))


ax.scatter(drc_data['magRaw_v']-drc_data['magRaw_i'],drc_data['magRaw_v'],\
           label='DRC',s=5,alpha=0.5,color='coral')
# ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
#            label='FLC',s=5,alpha=0.5,color='dodgerblue')

# ax.scatter(pix_d6['mean_f606w']-pix_d6['mean_f814w'],pix_d6['mean_f606w'],
#            label='FLC',s=5,alpha=0.5,color='')

ax.legend(fontsize=16)
ax.set_ylim(28.8,17.8)
ax.set_xlim(-1.5,1)
ax.set_xlabel('v-i',fontsize=16)
ax.set_ylabel(r'm$_V$',fontsize=16)
ax.tick_params(axis='both', labelsize=12)


plt.savefig('images/flc_drc_cmd_qual.png')

# %%
fig,ax = plt.subplots(figsize=(4,5))


ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')
ax.scatter(drc_data['magRaw_v']-drc_data['magRaw_i'],drc_data['magRaw_v'],\
           label='DRC',s=5,alpha=0.5,color='coral')


ax.legend(fontsize=16)
ax.set_ylim(25,21)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/msto_drc_flc.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


ax.scatter(matt_aper['m606c']-matt_aper['m814c'],matt_aper['m606c'],\
           label='APER',s=5,alpha=0.5,color='magenta')
ax.scatter(matt_psf['m606c']-matt_psf['m814c'],matt_psf['m606c'],\
           label='PSF',s=5,alpha=0.5,color='seagreen')


ax.legend(fontsize=16)
ax.set_ylim(30,16)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/aper_psf.png')

# %%
fig,ax = plt.subplots(figsize=(4,5))


ax.scatter(matt_aper['m606c']-matt_aper['m814c'],matt_aper['m606c'],\
           label='APER',s=5,alpha=0.5,color='magenta')
ax.scatter(matt_psf['m606c']-matt_psf['m814c'],matt_psf['m606c'],\
           label='PSF',s=5,alpha=0.5,color='seagreen')


ax.legend(fontsize=16)
ax.set_ylim(25,21)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/msto_aper_psf.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


ax.scatter(matt_aper['m606c']-matt_aper['m814c'],matt_aper['m606c'],\
           label='APER',s=5,alpha=0.5,color='magenta')

ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')
# ax.scatter(matt_psf['m606c']-matt_psf['m814c'],matt_psf['m606c'],\
#            label='PSF',s=5,alpha=0.5)


ax.legend(fontsize=16)
ax.set_ylim(29.5,16)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
# plt.savefig('images/msto_drc_flc.png')
plt.savefig('images/aper_flc.png')

# %%
fig,ax = plt.subplots(figsize=(4,5))


ax.scatter(matt_aper['m606c']-matt_aper['m814c'],matt_aper['m606c'],\
           label='APER',s=5,alpha=0.5,color='magenta')

ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')


ax.legend(fontsize=16)
ax.set_ylim(25,21)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/msto_aper_flc.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


# ax.scatter(matt_aper['m606c']-matt_aper['m814c'],matt_aper['m606c'],\
#            label='APER',s=5,alpha=0.5,color='magenta')


ax.scatter(matt_psf['m606c']-matt_psf['m814c'],matt_psf['m606c'],\
           label='PSF',s=5,alpha=0.5,color='seagreen')
ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')

ax.legend(fontsize=16)
ax.set_ylim(29.5,16)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/psf_flc.png')
# plt.savefig('aper_flc.png')

# %%
fig,ax = plt.subplots(figsize=(4,5))


ax.scatter(matt_psf['m606c']-matt_psf['m814c'],matt_psf['m606c'],\
           label='PSF',s=5,alpha=0.5,color='seagreen')
ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')


ax.legend(fontsize=16)
ax.set_ylim(25,21)
ax.set_xlim(-1.,0.25)
ax.set_xlabel('F606W-F814W',fontsize=16)
ax.set_ylabel('F606W',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/msto_aper_flc.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


# ax.scatter(matt_aper['m606c']-matt_aper['m814c'],matt_aper['m606c'],\
#            label='APER',s=5,alpha=0.5,color='magenta')


# ax.scatter(matt_psf['m606c']-matt_psf['m814c'],matt_psf['m606c'],\
#            label='PSF',s=5,alpha=0.5,color='seagreen')
# ax.scatter(flc_data_606['median']-flc_data_814['median'],flc_data_606['median'],\
#            label='FLC',s=5,alpha=0.5,color='dodgerblue')

ax.scatter(flc_data_606['median'],flc_data_606['stdev'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')
ax.scatter(drc_data['magRaw_v'],drc_data['magErr_v'],\
          label='DRC',s=5,alpha=0.5,color='coral')

ax.legend(fontsize=16)
ax.set_ylim(-0.01,1.5)
ax.set_xlim(18,28)
ax.set_xlabel('F606W',fontsize=16)
ax.set_ylabel('STDEV',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/err_flc_drc.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


ax.scatter(matt_aper['m606c'],matt_aper['s606'],\
           label='APER',s=5,alpha=0.5,color='magenta')


ax.scatter(flc_data_606['median'],flc_data_606['stdev'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')
# ax.scatter(drc_data['magRaw_v'],drc_data['magErr_v'],\
#           label='DRC',s=5,alpha=0.5,color='coral')



ax.legend(fontsize=16)
ax.set_ylim(-0.01,1.5)
ax.set_xlim(18,28)
ax.set_xlabel('F606W',fontsize=16)
ax.set_ylabel('STDEV',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/err_flc_aper.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


ax.scatter(matt_psf['m606c'],matt_psf['s606'],\
           label='PSF',s=5,alpha=0.5,color='seagreen')


ax.scatter(flc_data_606['median'],flc_data_606['stdev'],\
           label='FLC',s=5,alpha=0.5,color='dodgerblue')
# ax.scatter(drc_data['magRaw_v'],drc_data['magErr_v'],\
#           label='DRC',s=5,alpha=0.5,color='coral')



ax.legend(fontsize=16)
ax.set_ylim(-0.01,1.5)
ax.set_xlim(18,28)
ax.set_xlabel('F606W',fontsize=16)
ax.set_ylabel('STDEV',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
plt.savefig('images/err_flc_psf.png')

# %%
fig,ax = plt.subplots(figsize=(8,10))


ax.scatter(matt_psf['m606c'],matt_psf['s606'],\
           label='PSF',s=5,alpha=0.5,color='seagreen')

ax.scatter(drc_data['magRaw_v'],drc_data['magErr_v'],\
          label='DRC',s=5,alpha=0.5,color='coral')
# ax.scatter(flc_data_606['median'],flc_data_606['stdev'],\
#            label='FLC',s=5,alpha=0.5,color='dodgerblue')
# ax.scatter(drc_data['magRaw_v'],drc_data['magErr_v'],\
#           label='DRC',s=5,alpha=0.5,color='coral')

ax.scatter(matt_aper['m606c'],matt_aper['s606'],\
           label='APER',s=5,alpha=0.5,color='magenta')


ax.legend(fontsize=16)
ax.set_ylim(-0.01,1.5)
ax.set_xlim(18,28)
ax.set_xlabel('F606W',fontsize=16)
ax.set_ylabel('STDEV',fontsize=16)
ax.tick_params(axis='both', labelsize=12)

# plt.show()
# plt.savefig('images/err_flc_psf.png')
