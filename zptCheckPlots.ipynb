# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.genfromtxt('mattia/HOROLOGIUM-I_mag_zpt_std_all.dat', # 01/18
                     names=True)
data2 = np.genfromtxt('mattia/HOROLOGIUM-I_mag_zpt_std_all_2301.dat',
                     names=True)
data3 = np.genfromtxt('mattia/HOROLOGIUM-I_mag_zpt_std_all_2801.dat',
                     names=True)
# data4 = np.genfromtxt('mattia/zpt_tight_1801.dat',
#                      names=True)
psf= np.genfromtxt('elena_cats/HOROLOGIUM_CF.1.PSF.CAT',names=True)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)

ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')
# ax2.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)

ax2.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f606w'],label='ZPT Adjusted 2',alpha=0.5,color='thistle')

ax3.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7,color='darkorange')
ax3.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f606w'],label='ZPT Adjusted 2',alpha=0.5,color='thistle')


ax1.set_ylim(27,17.5)
ax1.set_xlim(-1,0.5)

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

# ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)

# ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')
ax1.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
           data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)

ax2.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)
ax2.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f606w'],label='ZPT Adjusted 2',alpha=0.5,color='thistle')

# ax3.scatter(data['mean_f606w']-data['mean_f814w'],
#            data['mean_f606w'],label='Non-Adjusted',alpha=0.7,color='darkorange')
ax3.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
           data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5,color='darkorange')
ax3.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f606w'],label='ZPT Adjusted 2',alpha=0.5,color='thistle')


ax1.set_ylim(27,17.5)
ax1.set_xlim(-1,0.5)

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f814w'],label='Non-Adjusted',alpha=0.7)

ax2.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')
# ax2.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)

ax2.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f814w'],label='ZPT Adjusted 2',alpha=0.5,color='thistle')

ax3.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f814w'],label='Non-Adjusted',alpha=0.7,color='darkorange')
ax3.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f814w'],label='ZPT Adjusted 2',alpha=0.5,color='thistle')


ax1.set_ylim(27,17.5)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F814W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)

ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')
# ax2.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)

ax2.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f606w'],label='ZPT Adjusted 3',alpha=0.5,color='mediumpurple')

ax3.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7,color='darkorange')
ax3.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f606w'],label='ZPT Adjusted 3',alpha=0.5,color='mediumpurple')


ax1.set_ylim(27,17.5)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)

ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')
# ax2.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)

ax2.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f606w'],label='ZPT Adjusted 3',alpha=0.5,color='mediumpurple')

# ax3.scatter(data['mean_f606w']-data['mean_f814w'],
#            data['mean_f606w'],label='Non-Adjusted',alpha=0.7,color='darkorange')
ax3.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f606w'],label='ZPT Adjusted 2',alpha=0.5,color='magenta')
ax3.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f606w'],label='ZPT Adjusted 3',alpha=0.5,color='mediumpurple')


ax1.set_ylim(27,17.5)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F606W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f814w'],label='Non-Adjusted',alpha=0.7)

ax2.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')
# ax2.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)

ax2.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f814w'],label='ZPT Adjusted 3',alpha=0.5,color='mediumpurple')

ax3.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f814w'],label='Non-Adjusted',alpha=0.7,color='darkorange')
ax3.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f814w'],label='ZPT Adjusted 3',alpha=0.5,color='mediumpurple')


ax1.set_ylim(27,17.5)
ax1.set_xlim(-1,0.5)
ax1.set_ylabel('F814W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
# fig,ax = plt.subplots(figsize=(5,7))
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')
ax2.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')
# ax3.scatter(psf['m606c']-psf['m814c'],psf['m606c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)
# ax.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)
ax2.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f606w'],label='ZPT Adjusted 2',alpha=0.5)


ax3.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f606w'],label='Non-Adjusted',alpha=0.7)
ax3.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f606w'],label='ZPT Adjusted 3',alpha=0.5)


ax1.set_ylim(24,22)
ax1.set_xlim(-1,0.5)

ax1.legend()
ax2.legend()
ax3.legend()

ax1.set_ylabel('F606W')

plt.show()

# %%
# fig,ax = plt.subplots(figsize=(5,7))
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')
ax2.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')
ax3.scatter(psf['m606c']-psf['m814c'],psf['m814c'],label='PSF')

ax1.scatter(data['mean_f606w']-data['mean_f814w'],
           data['mean_f814w'],label='Non-Adjusted',alpha=0.7)
# ax.scatter(data['zpt_mean_f606w']-data['zpt_mean_f814w'],
#            data['zpt_mean_f606w'],label='ZPT Adjusted',alpha=0.5)
ax2.scatter(data2['zpt_mean_f606w']-data2['zpt_mean_f814w'],
           data2['zpt_mean_f814w'],label='ZPT Adjusted 2',alpha=0.5)
ax3.scatter(data3['zpt_mean_f606w']-data3['zpt_mean_f814w'],
           data3['zpt_mean_f814w'],label='ZPT Adjusted 3',alpha=0.5)


ax1.set_ylim(24,22)
ax1.set_xlim(-1,0.5)

ax1.legend()
ax2.legend()
ax3.legend()

ax1.set_ylabel('F814W')

plt.show()

# %%
# fig,ax = plt.subplots(figsize=(7,5))
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(18,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c'],psf['s606'],label='PSF')
ax2.scatter(psf['m606c'],psf['s606'],label='PSF')
ax3.scatter(psf['m606c'],psf['s606'],label='PSF')
# ax.scatter(data['zpt_mean_f606w'],data['zpt_std_f606w'],
#            label='ZPT Adjusted')

ax1.scatter(data['mean_f606w'],data['stdev_f606w'],
           label='Non-Adjusted')

ax2.scatter(data['mean_f606w'],data['stdev_f606w'],
           label='Non-Adjusted')
ax2.scatter(data2['zpt_mean_f606w'],data2['zpt_std_f606w'],
           label='ZPT Adjusted 2')

ax3.scatter(data['mean_f606w'],data['stdev_f606w'],
           label='Non-Adjusted')
ax3.scatter(data3['zpt_mean_f606w'],data3['zpt_std_f606w'],
           label='ZPT Adjusted 3')

ax1.set_ylim(0,0.5)
ax1.set_xlim(16.5,27)

ax1.set_ylabel('STDEV_F606W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
# fig,ax = plt.subplots(figsize=(7,5))
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(18,6),sharey=True,sharex=True)

ax1.scatter(psf['m814c'],psf['s814'],label='PSF')
ax2.scatter(psf['m814c'],psf['s814'],label='PSF')
ax3.scatter(psf['m814c'],psf['s814'],label='PSF')
# ax.scatter(data['zpt_mean_f814w'],data['zpt_std_f814w'],
#            label='ZPT Adjusted')

ax1.scatter(data['mean_f814w'],data['stdev_f814w'],
           label='Non-Adjusted')

ax2.scatter(data['mean_f814w'],data['stdev_f814w'],
           label='Non-Adjusted')
ax2.scatter(data2['zpt_mean_f814w'],data2['zpt_std_f814w'],
           label='ZPT Adjusted 2')

ax3.scatter(data['mean_f814w'],data['stdev_f814w'],
           label='Non-Adjusted')
ax3.scatter(data3['zpt_mean_f814w'],data3['zpt_std_f814w'],
           label='ZPT Adjusted 3')

ax1.set_ylim(0,0.5)
ax1.set_xlim(16.5,27)

ax1.set_ylabel('STDEV_F814W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()

# %%
# fig,ax = plt.subplots(figsize=(7,5))
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(18,6),sharey=True,sharex=True)

ax1.scatter(psf['m606c'],psf['s606'],label='PSF')
ax2.scatter(psf['m606c'],psf['s606'],label='PSF')
# ax3.scatter(psf['m606c'],psf['s606'],label='PSF')
# ax.scatter(data['zpt_mean_f606w'],data['zpt_std_f606w'],
#            label='ZPT Adjusted')

ax1.scatter(data['mean_f606w'],data['stdev_f606w'],
           label='Non-Adjusted')
ax1.scatter(data['zpt_mean_f606w'],data['zpt_std_f606w'],
           label='ZPT Adjusted')

ax2.scatter(data['mean_f606w'],data['stdev_f606w'],
           label='Non-Adjusted')
ax2.scatter(data2['zpt_mean_f606w'],data2['zpt_std_f606w'],
           label='ZPT Adjusted 2')


ax3.scatter(data['zpt_mean_f606w'],data['zpt_std_f606w'],
           label='ZPT Adjusted')
ax3.scatter(data2['zpt_mean_f606w'],data2['zpt_std_f606w'],
           label='ZPT Adjusted 2',alpha=0.5)
# ax3.scatter(data['mean_f606w'],data['stdev_f606w'],
#            label='Non-Adjusted')
# ax3.scatter(data3['zpt_mean_f606w'],data3['zpt_std_f606w'],
#            label='ZPT Adjusted 3')

ax1.set_ylim(0,0.5)
ax1.set_xlim(16.5,27)

ax1.set_ylabel('STDEV_F606W')

ax1.legend()
ax2.legend()
ax3.legend()

plt.show()
